# %% [markdown]
# # Data Collection and Loading
#
# This notebook explains how the dataset was created and loaded for analysis.

# %% [markdown]
# ## Data Collection
#
# The dataset was manually created based on personal menstrual cycle tracking data.
#
# Each row represents a single day and includes information such as:
# - cycle day
# - bleeding status
# - flow level
# - cramps
# - headache
# - mood
# - energy

# %%
import pandas as pd
from google.colab import files

uploaded = files.upload()

df = pd.read_csv("clue_daily_data.csv")
# Out:
#      <input type="file" id="files-6b802edf-5ab3-40c4-be7b-ed48f8b9d5ed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6b802edf-5ab3-40c4-be7b-ed48f8b9d5ed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head()
# Out:
#          date  cycle_id  cycle_day  bleeding  flow_level  cramps  headache  \
# 0  2025-10-24         1          1         1           3       3         1
# 1  2025-10-25         1          2         1           2       3         0
# 2  2025-10-26         1          3         1           2       2         0
# 3  2025-10-27         1          4         1           1       1         0
# 4  2025-10-28         1          5         1           1       0         0
#
#    mood  energy
# 0     2       1
# 1     2       2
# 2     2       2
# 3     3       3
# 4     3       3

# %% [markdown]
# ## Data Overview
#
# The dataset contains daily records of menstrual cycle symptoms over multiple months.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        165 non-null    object
#  1   cycle_id    165 non-null    int64
#  2   cycle_day   165 non-null    int64
#  3   bleeding    165 non-null    int64
#  4   flow_level  165 non-null    int64
#  5   cramps      165 non-null    int64
#  6   headache    165 non-null    int64
#  7   mood        165 non-null    int64
#  8   energy      165 non-null    int64
# dtypes: int64(8), object(1)
# memory usage: 11.7+ KB
